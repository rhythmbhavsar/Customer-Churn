# %% [markdown]
# # Data Description
#
# ### 7043 observations with 33 variables
#
# -  CustomerID: A unique ID that identifies each customer.
# -  Count: A value used in reporting/dashboarding to sum up the number of customers in a filtered set.
# -  Country: The country of the customer’s primary residence.
# -  State: The state of the customer’s primary residence.
# -  City: The city of the customer’s primary residence.
# -  Zip Code: The zip code of the customer’s primary residence.
# -  Lat Long: The combined latitude and longitude of the customer’s primary residence.
# -  Latitude: The latitude of the customer’s primary residence.
# -  Longitude: The longitude of the customer’s primary residence.
# -  Gender: The customer’s gender: Male, Female
# -  senior Citizen: Indicates if the customer is 65 or older: Yes, No
# -  Partner: Indicate if the customer has a partner: Yes, No
# -  Dependents: Indicates if the customer lives with any dependents: Yes, No. Dependents could be children, parents, grandparents, etc.
# -  Tenure Months: Indicates the total amount of months that the customer has been with the company by the end of the quarter specified above.
# -  Phone Service: Indicates if the customer subscribes to home phone service with the company: Yes, No
# -  Multiple Lines: Indicates if the customer subscribes to multiple telephone lines with the company: Yes, No
# -  Internet Service: Indicates if the customer subscribes to Internet service with the company: No, DSL, Fiber Optic, Cable.
# -  Online Security: Indicates if the customer subscribes to an additional online security service provided by the company: Yes, No
# -  Online Backup: Indicates if the customer subscribes to an additional online backup service provided by the company: Yes, No
# -  Device Protection: Indicates if the customer subscribes to an additional device protection plan for their Internet equipment provided by the company: Yes, No
# -  Tech Support: Indicates if the customer subscribes to an additional technical support plan from the company with reduced wait times: Yes, No
# -  Streaming TV: Indicates if the customer uses their Internet service to stream television programing from a third party provider: Yes, No. The company does not charge an additional fee for this service.
# -  Streaming Movies: Indicates if the customer uses their Internet service to stream movies from a third party provider: Yes, No. The company does not charge an additional fee for this service.
# -  Contract: Indicates the customer’s current contract type: Month-to-Month, One Year, Two Year.
# -  Paperless Billing: Indicates if the customer has chosen paperless billing: Yes, No
# -  Payment Method: Indicates how the customer pays their bill: Bank Withdrawal, Credit Card, Mailed Check
# -  Monthly Charge: Indicates the customer’s current total monthly charge for all their services from the company.
# -  Total Charges: Indicates the customer’s total charges, calculated to the end of the quarter specified above.
# -  Churn Label: Yes = the customer left the company this quarter. No = the customer remained with the company. Directly related to Churn Value.
# -  Churn Value: 1 = the customer left the company this quarter. 0 = the customer remained with the company. Directly related to Churn Label.
# -  Churn Score: A value from 0-100 that is calculated using the predictive tool IBM SPSS Modeler. The model incorporates multiple factors known to cause churn. The higher the score, the more likely the customer will churn.
# -  CLTV: Customer Lifetime Value. A predicted CLTV is calculated using corporate formulas and existing data. The higher the value, the more valuable the customer. High value customers should be monitored for churn.
# -  Churn Reason: A customer’s specific reason for leaving the company. Directly related to Churn Category.

# %%
#importing important python libraries
import numpy as np # this library is used for dealing with arrays and numerical values
import pandas as pd # this library is used for dealing with dataframes
import matplotlib.pyplot as plt # this library is used for visulization
import seaborn as sns # this library is used for visulization
import missingno as msno # this library is used for visualising mssing values
# %matplotlib inline
sns.set(rc={'figure.figsize':(10,6)})

# %% [markdown]
# ## Q1: Please read the file and explain data types statistically as well as how python is reading it. Please let us know if any data type is read wrong.

# %%
# Here we are laoding the dataset
churn = pd.read_csv("Telco_customer_churn.csv")
pd.pandas.set_option('display.max_columns',None)

# %%
churn.head(10)
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
# 5  4190-MFLUW      1  United States  California  Los Angeles     90020
# 6  8779-QRDMV      1  United States  California  Los Angeles     90022
# 7  1066-JKSGK      1  United States  California  Los Angeles     90024
# 8  6467-CHFZW      1  United States  California  Los Angeles     90028
# 9  8665-UTDHZ      1  United States  California  Los Angeles     90029
#
#                  Lat Long   Latitude   Longitude  Gender Senior Citizen  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male             No
# ...

# %%
# Checking the datatypes for all the columns
churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
# ...

# %% [markdown]
# Here as we can see **Total Charges** column is readed as a oject datatype becuase it is containing **"  "** data in it.
#
# So we will replace the **" "** with **None** values and then we will drop the null values.
#
# And at last we will change the datatype of the column to **Float** by using **to_numeric()** function.
#
# Also **zip code** is laoded as **int** datatype we have to convert it into **categorical**

# %%
#  Replacing the " " values with NONE and dropping values
churn['Total Charges'] = churn['Total Charges'].replace({" ": None})
churn['Total Charges'].dropna()
churn
# Out:
#       CustomerID  Count        Country       State          City  Zip Code  \
# 0     3668-QPYBK      1  United States  California   Los Angeles     90003
# 1     9237-HQITU      1  United States  California   Los Angeles     90005
# 2     9305-CDSKC      1  United States  California   Los Angeles     90006
# 3     7892-POOKP      1  United States  California   Los Angeles     90010
# 4     0280-XJGEX      1  United States  California   Los Angeles     90015
# ...          ...    ...            ...         ...           ...       ...
# 7038  2569-WGERO      1  United States  California       Landers     92285
# 7039  6840-RESVB      1  United States  California      Adelanto     92301
# 7040  2234-XADUH      1  United States  California         Amboy     92304
# 7041  4801-JZAZL      1  United States  California  Angelus Oaks     92305
# 7042  3186-AJIEK      1  United States  California  Apple Valley     92308
#
# ...

# %%
# Changing datatype to float
churn['Total Charges'] = pd.to_numeric(churn['Total Charges'])
churn['Zip Code'] = churn['Zip Code'].astype('category')

# %%
churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   category
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
# ...

# %% [markdown]
# As we can see here all the data are readed properly now.

# %% [markdown]
# ## Q2: Please apply appropriate statistical measures using python based on data types.

# %% [markdown]
# **Statistical measures** are a **descriptive analysis** technique used to summarise the characteristics of a data set. This data set can represent the whole population or a sample of it. Statistical measures can be classified as measures of central tendency and measures of spread.
#
# Measure of **central tendancy** can be done for the **numerical** type of data.
# Measure of central tendancy consists of:-
# -  Mean
# -  Median
# -  Mode
#
# For **catgorical** datas we can use measure of **spreads**. It contains:-
# -  Counts
# -  Number of Unique values
# -  Top values

# %%
# Performing statistical measures fro numerical data only
churn.describe()
# Out:
#         Count     Latitude    Longitude  Tenure Months  Monthly Charges  \
# count  7043.0  7043.000000  7043.000000    7043.000000      7043.000000
# mean      1.0    36.282441  -119.798880      32.371149        64.761692
# std       0.0     2.455723     2.157889      24.559481        30.090047
# min       1.0    32.555828  -124.301372       0.000000        18.250000
# 25%       1.0    34.030915  -121.815412       9.000000        35.500000
# 50%       1.0    36.391777  -119.730885      29.000000        70.350000
# 75%       1.0    38.224869  -118.043237      55.000000        89.850000
# max       1.0    41.962127  -114.192901      72.000000       118.750000
#
#        Total Charges  Churn Value  Churn Score         CLTV
# count    7032.000000  7043.000000  7043.000000  7043.000000
# mean     2283.300441     0.265370    58.699418  4400.295755
# std      2266.771362     0.441561    21.525131  1183.057152
# min        18.800000     0.000000     5.000000  2003.000000
# ...

# %%
# Performing statistical measures fro categorical data only
churn.describe(include='object')
# Out:
#         CustomerID        Country       State         City  \
# count         7043           7043        7043         7043
# unique        7043              1           1         1129
# top     3668-QPYBK  United States  California  Los Angeles
# freq             1           7043        7043          305
#
#                       Lat Long Gender Senior Citizen Partner Dependents  \
# count                     7043   7043           7043    7043       7043
# unique                    1652      2              2       2          2
# top     33.964131, -118.272783   Male             No      No         No
# freq                         5   3555           5901    3641       5416
#
#        Phone Service Multiple Lines Internet Service Online Security  \
# count           7043           7043             7043            7043
# unique             2              3                3               3
# top              Yes             No      Fiber optic              No
# ...

# %% [markdown]
# ## Q3: What is the percentage of females and senior citizens in this data set? Please create appropriate plots and explain the plots.

# %% [markdown]
# Here we are supposed to find the percentage of females and senior citizens in this data set.
#
# From this there are 2 possible answers.
#
# 1.  They are supposing to find the individual percentage for females and the senior citizens
# 2.  They are supposing to find the percentage for females who are senior citizens.

# %%
# Plotting pie plot for analysing percentage between males and females
churn.groupby('Gender').size().plot(kind='pie', autopct='%.2f%%')
plt.ylabel("Percentage between males and females")
# Out:
# Text(0, 0.5, 'Percentage between males and females')

# %% [markdown]
# Here the percentage of **Male** is **50.48%** and **Female** is **49.52%**.

# %%
# Plotting pie plot for analysing percentage between Senior Citizens
churn.groupby('Senior Citizen').size().plot(kind='pie', autopct='%.2f%%')
plt.ylabel("Percentage between Senior Citizen")
# Out:
# Text(0, 0.5, 'Percentage between Senior Citizen')

# %% [markdown]
# Here the percentage of **Senior Citizen** is **16.21%** and **not Senior Citizen** is **83.79%**.

# %% [markdown]
# ### Plotting graph for the females who senion citizen

# %%
# making dataset which only contains Females data
only_female = churn[churn['Gender'] == 'Female']

# %%
# Plotting pie plot for analysing percentage for females who are sinion citizens
only_female.groupby('Senior Citizen').size().plot(kind='pie', autopct='%.2f%%')
plt.ylabel("Percentage for females who are sinior citizens")
# Out:
# Text(0, 0.5, 'Percentage for females who are sinior citizens')

# %% [markdown]
# Here **16.28%** of senior citezens are females

# %% [markdown]
# ## Q4:  Please create an appropriate plot to examine the distribution of the tenure month column and explain the distribution. Based on distribution, perform appropriate statistical measures. Please also explain if the variable is symmetric or skewed. Please calculate it. Explain everything as asked.

# %%
# Plotting histogram for analysing distribution of Tenure Months column
sns.histplot(x=churn['Tenure Months'], kde=True)
plt.axvline(x=churn['Tenure Months'].mean(),ls='--',lw=2.5, color='blue',label='mean')
plt.axvline(x=churn['Tenure Months'].median(), color='blue',label='medain')

# %%
# Finding skeness value with the help of skew() function
churn['Tenure Months'].skew()
# Out:
# 0.2395397495619829

# %% [markdown]
# Here the data seems that it is **symetrically/Normally** distributed.
#
# The skewness value for the **'Tenure Month'** is **0.2395397495619829**
#
# The best measure of spread when the **median** is the center is the **IQR** when the data is **skewed**. As for when the center is the **mean**, then **standard deviation** should be used since it measure the distance between a data point and the mean for the symetrical data.
#
#
# Here as the data is normally ditributed we are using **median** for the central tendancy. Therefore, we will use **Standard Deviation** to find the despersion.

# %%
# Finding mean value
churn['Tenure Months'].mean()
# Out:
# 32.37114865824223

# %%
# Finding standard deviation
churn['Tenure Months'].std()
# Out:
# 24.55948102309432

# %% [markdown]
# -  Mean :- **32.37114865824223**
# -  Standard Deviation :- **24.55948102309432**

# %% [markdown]
# ## Q5: Please convert all binary columns into 0 and 1 using appropriate programming constructs, not one by one.

# %% [markdown]
# Here the binary columns are :-
#
# -  Senior Citizen
# -  Partner
# -  Dependents
# -  Phone Service
# -  Churn Label
# -  Multiple Lines
# -  Online Security
# -  Online Backup
# -  Device Protection
# -  Tech Support
# -  Streaming TV
# -  Streaming Movies
# -  Paperless Billing
#
# We are replacing the **yes** value with **1** and **No** value with **0**.
#
# And also we had analysed that this columns also contains **'No phone service':-1** or **'No internet service'** which can be the error while collecting the data so we are replacing them with **-1**.
#
# Infuture if we proced for Machine Learning or EDA part we can drop the error data easily by droping -1 values

# %%
#  Maki8ng the copy of original dataset
churn1 = churn.copy()
churn1.head()
# Out:
#    CustomerID  Count        Country       State         City Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles    90003
# 1  9237-HQITU      1  United States  California  Los Angeles    90005
# 2  9305-CDSKC      1  United States  California  Los Angeles    90006
# 3  7892-POOKP      1  United States  California  Los Angeles    90010
# 4  0280-XJGEX      1  United States  California  Los Angeles    90015
#
#                  Lat Long   Latitude   Longitude  Gender Senior Citizen  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male             No
# 1   34.059281, -118.30742  34.059281 -118.307420  Female             No
# 2  34.048013, -118.293953  34.048013 -118.293953  Female             No
# 3  34.062125, -118.315709  34.062125 -118.315709  Female             No
# 4  34.039224, -118.266293  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure Months Phone Service Multiple Lines  \
# ...

# %%
# Storing all the column names in the list
binary_columns = ['Senior Citizen', 'Partner', 'Dependents', 'Phone Service', 'Churn Label', 
                  'Multiple Lines', 'Online Security', 'Online Backup', 'Device Protection',
                 'Tech Support', 'Streaming TV', 'Streaming Movies', 'Paperless Billing']

# %%
# Replacing the values
for i in binary_columns:
    churn1[i] = churn1[i].replace({'Yes':1 ,'No':0,'No phone service':-1, 'No internet service':-1})

#  Now we replaced the values with -1, 1 and 0 we have to change its datatype to category
# Therefore changing datatypes to category
churn1[binary_columns] = churn1[binary_columns].astype('category')

# %%
churn1.head(10)
# Out:
#    CustomerID  Count        Country       State         City Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles    90003
# 1  9237-HQITU      1  United States  California  Los Angeles    90005
# 2  9305-CDSKC      1  United States  California  Los Angeles    90006
# 3  7892-POOKP      1  United States  California  Los Angeles    90010
# 4  0280-XJGEX      1  United States  California  Los Angeles    90015
# 5  4190-MFLUW      1  United States  California  Los Angeles    90020
# 6  8779-QRDMV      1  United States  California  Los Angeles    90022
# 7  1066-JKSGK      1  United States  California  Los Angeles    90024
# 8  6467-CHFZW      1  United States  California  Los Angeles    90028
# 9  8665-UTDHZ      1  United States  California  Los Angeles    90029
#
#                  Lat Long   Latitude   Longitude  Gender Senior Citizen  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male              0
# ...

# %% [markdown]
# As we can see here the binary columns values are replaced by **1, 0** and **-1**

# %% [markdown]
# ## Q6.  Please examine the distribution of monthly charges between males and females using box plots. Please explain the results also.

# %%
# Plotting box plot for Monthly Charges vs Gender
sns.boxplot(y=churn['Monthly Charges'], x=churn['Gender'])
plt.xlabel("Gender")
plt.ylabel("Monthly charges")
plt.title("Gender vs Monthly charges", fontname="Times New Roman", size=28,fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Gender vs Monthly charges')

# %% [markdown]
# Here it seems like there is no major difference in monthly chages between Male and females.

# %% [markdown]
# ## Q7: Please find what is the minimum total charges for Los Angeles city. Please find which zip code has the maximum total charges.

# %%
# Filtering and sorting values for Total Charges for minimum value
churn[churn['Total Charges'] == churn['Total Charges'].min()]
# Out:
#       CustomerID  Count        Country       State         City Zip Code  \
# 3087  2967-MXRAV      1  United States  California  Los Angeles    90003
#
#                     Lat Long   Latitude   Longitude Gender Senior Citizen  \
# 3087  33.964131, -118.272783  33.964131 -118.272783   Male             No
#
#      Partner Dependents  Tenure Months Phone Service Multiple Lines  \
# 3087     Yes         No              1           Yes             No
#
#      Internet Service      Online Security        Online Backup  \
# 3087               No  No internet service  No internet service
#
#         Device Protection         Tech Support         Streaming TV  \
# 3087  No internet service  No internet service  No internet service
#
#          Streaming Movies  Contract Paperless Billing Payment Method  \
# 3087  No internet service  One year                No   Mailed check
#
#       Monthly Charges  Total Charges Churn Label  Churn Value  Churn Score  \
# ...

# %% [markdown]
# **18.8** is the minimum total charges for Los Angeles city.

# %%
# Filtering and sorting values for Total Charges for minimum value
churn[churn['Total Charges'] == churn['Total Charges'].max()]
# Out:
#       CustomerID  Count        Country       State           City Zip Code  \
# 1206  2889-FPWRM      1  United States  California  Mckinleyville    95519
#
#                     Lat Long   Latitude   Longitude Gender Senior Citizen  \
# 1206  40.965011, -124.015255  40.965011 -124.015255   Male             No
#
#      Partner Dependents  Tenure Months Phone Service Multiple Lines  \
# 1206     Yes         No             72           Yes            Yes
#
#      Internet Service Online Security Online Backup Device Protection  \
# 1206      Fiber optic             Yes           Yes               Yes
#
#      Tech Support Streaming TV Streaming Movies  Contract Paperless Billing  \
# 1206          Yes          Yes              Yes  One year               Yes
#
#                  Payment Method  Monthly Charges  Total Charges Churn Label  \
# 1206  Bank transfer (automatic)            117.8         8684.8         Yes
#
#       Churn Value  Churn Score  CLTV  \
# ...

# %% [markdown]
# **95519** is the zip code which has the maximum total charges.

# %% [markdown]
# ## Q8: Please find which payment method has the highest churn score and which has the lowest churn score.

# %%
churn[churn['Churn Score'] == churn['Churn Score'].min()]
# Out:
#       CustomerID  Count        Country       State       City Zip Code  \
# 2148  7156-MXBJE      1  United States  California  San Diego    92127
#
#                     Lat Long   Latitude   Longitude  Gender Senior Citizen  \
# 2148  33.017518, -117.118456  33.017518 -117.118456  Female             No
#
#      Partner Dependents  Tenure Months Phone Service Multiple Lines  \
# 2148      No         No             43           Yes            Yes
#
#      Internet Service Online Security Online Backup Device Protection  \
# 2148              DSL              No           Yes               Yes
#
#      Tech Support Streaming TV Streaming Movies  Contract Paperless Billing  \
# 2148          Yes          Yes              Yes  One year                No
#
#                Payment Method  Monthly Charges  Total Charges Churn Label  \
# 2148  Credit card (automatic)             85.1        3662.25          No
#
#       Churn Value  Churn Score  CLTV Churn Reason
# ...

# %% [markdown]
# **Credit card (automatic)**  has the lowest churn score.

# %%
churn[churn['Churn Score'] == churn['Churn Score'].max()]
# Out:
#       CustomerID  Count        Country       State             City Zip Code  \
# 6     8779-QRDMV      1  United States  California      Los Angeles    90022
# 39    3445-HXXGF      1  United States  California     Sierra Madre    91024
# 100   0533-BNWKF      1  United States  California      Palm Desert    92211
# 151   1009-IRMNA      1  United States  California     Port Hueneme    93041
# 189   3900-AQPHZ      1  United States  California      Pearblossom    93553
# 226   3804-RVTGV      1  United States  California    Mountain View    94043
# 279   5536-RTPWK      1  United States  California        Sausalito    94965
# 288   4607-CHPCA      1  United States  California       San Martin    95046
# 439   5364-XYIRR      1  United States  California      Los Angeles    90013
# 458   3198-VELRD      1  United States  California   Marina Del Rey    90292
# 565   9787-XVQIU      1  United States  California        Sugarloaf    92386
# ...

# %% [markdown]
# **Electronic check** has the highest churn score

# %%
sns.barplot(y=churn['Churn Score'], x=churn['Payment Method'])
plt.xlabel("Payment Method")
plt.ylabel("Churn Score")
plt.title("Payment Method vs Churn Score", fontname="Times New Roman", size=28,fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Payment Method vs Churn Score')

# %% [markdown]
# By the upper plot it is clear that **Electronic check** has the **highest** chunk score and **Credit card (automatic)** has the **lowest**
# chunk score

# %% [markdown]
# ## Q9 Please create an appropriate plot to check the count of payment methods and explain it.

# %%
ax = sns.countplot(x=churn['Payment Method'])
plt.xlabel("Payment Method")
plt.title("Counting Payment Method", fontname="Times New Roman", size=28,fontweight="bold")

for p in ax.patches:
   ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))

# %% [markdown]
# Here the counts for the payment methods are as followed:-
#
# -  Mailed check = **1612**
# -  Electronic check = **2365**
# -  Bank transfer = **1544**
# -  Credit card = **1522**

# %% [markdown]
# ## Q10 Please create an appropriate plot to see the relationship between monthly charges and total charges.

# %%
sns.scatterplot(x=churn['Monthly Charges'], y=churn['Total Charges'])
plt.xlabel("Monthly Charges")
plt.ylabel("Total Charges")
plt.title("Total Charges vs Monthly charges", fontname="Times New Roman", size=28,fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Total Charges vs Monthly charges')

# %% [markdown]
# Here as we can see as the Monthly Charges are increasing Tortal Charges are also increasing parellely
